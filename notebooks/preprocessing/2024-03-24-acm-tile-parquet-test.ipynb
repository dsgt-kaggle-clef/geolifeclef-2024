# %%
import pandas as pd
import numpy as np

df = pd.read_parquet("/mnt/data/intermediate/tiles/0000/000000.parquet")
df
# Out:
#                                                   bio1  \
# 0    [0.19804762303829193, 0.19804762303829193, 0.2...
# 1    [0.19804762303829193, 0.19804762303829193, 0.2...
# 2    [0.19804762303829193, 0.19804762303829193, 0.2...
# 3    [0.19804762303829193, 0.19804762303829193, 0.2...
# 4    [0.19804762303829193, 0.19804762303829193, 0.2...
# ..                                                 ...
# 495  [0.19804762303829193, 0.19804762303829193, 0.2...
# 496  [0.19804762303829193, 0.19804762303829193, 0.2...
# 497  [0.19804762303829193, 0.19804762303829193, 0.2...
# 498  [0.19804762303829193, 0.19804762303829193, 0.2...
# 499  [0.19804762303829193, 0.19804762303829193, 0.2...
#
#                                                   bio2  \
# 0    [1.0623652935028076, 1.0623652935028076, 1.062...
# 1    [1.0623652935028076, 1.0623652935028076, 1.062...
# 2    [1.0623652935028076, 1.0623652935028076, 1.062...
# 3    [1.0623652935028076, 1.0623652935028076, 1.062...
# ...

# %%
df.columns
# Out:
# Index(['bio1', 'bio2', 'HFP2009_WGS84', 'red', 'green', 'blue', 'nir', 'lat',
#        'lon', 'surveyId', 'target'],
#       dtype='object')

# %%
for column in df.columns:
    row = df.iloc[0][column]
    if isinstance(row, np.ndarray):
        print(f"{column}: {len(row)}")
    else:
        print(f"{column}: {type(row)}")
# Out:
# bio1: 16384
# bio2: 16384
# HFP2009_WGS84: 16384
# red: 16384
# green: 16384
# blue: 16384
# nir: 16384
# lat: <class 'numpy.float64'>
# lon: <class 'numpy.float64'>
# surveyId: <class 'numpy.float64'>
# target: <class 'numpy.int64'>

# %%
from geolifeclef.utils import get_spark

spark = get_spark()
sdf = spark.read.parquet("/mnt/data/intermediate/tiles/0000/000000.parquet")
sdf.printSchema()
sdf.show(n=1, truncate=80, vertical=True)
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/03/24 13:23:47 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 24/03/24 13:23:47 WARN SparkConf: Note that spark.local.dir will be overridden by the value set by the cluster manager (via SPARK_LOCAL_DIRS in mesos/standalone/kubernetes and LOCAL_DIRS in YARN).
# root
#  |-- bio1: array (nullable = true)
#  |    |-- element: double (containsNull = true)
#  |-- bio2: array (nullable = true)
#  |    |-- element: double (containsNull = true)
#  |-- HFP2009_WGS84: array (nullable = true)
#  |    |-- element: double (containsNull = true)
#  |-- red: array (nullable = true)
#  |    |-- element: double (containsNull = true)
#  |-- green: array (nullable = true)
#  |    |-- element: double (containsNull = true)
#  |-- blue: array (nullable = true)
# ...

# %%
spark.stop()
